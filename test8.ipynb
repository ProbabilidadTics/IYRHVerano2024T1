# %%
import Ejercicios.Graficas as graf 
import Ejercicios.Tabla as tbl
import Ejercicios.DigDisyCua as disCua
import Ejercicios.DigCont as digCont


datosDecimal = [
    2.5,4.5,5.8,2.2,5.7,5.3,4.0,0.9,2.5,2.3,3.2,4.9,2.7,3.7,3.8,4.9,2.8,3.6,4.2,3.1,7.2,1.9,5.9,3.3,2.9,1.1,1.7,2.6,3.1,4.4
]

print("A. Son datos continuos")

clases, limsInf, limsSup, mrksClases, fa, fr, frAc = digCont.generateGroupedData(datosDecimal,1,6)
frStr, frAcStr = tbl.datosStrPorcentaje(fr, frAc)


encabezados = ["Clases", "L. Inferior", "L. Superior", "M. Clase", "F. Absoluta", "F. Relativa", "F. Acumulada"]
contenido = [clases, limsInf, limsSup, mrksClases, fa, frStr, frAcStr]
tbl.printHTMLTable(encabezados, contenido)


graf.createHistogram(mrksClases, fr) 
graf.createOjiva(mrksClases, frAc)
# Out:
# A. Son datos continuos
# <center><table><tr><th style='border: 1px #ccc solid; text-align: center;'>Clases</th><th style='border: 1px #ccc solid; text-align: center;'>L. Inferior</th><th style='border: 1px #ccc solid; text-align: center;'>L. Superior</th><th style='border: 1px #ccc solid; text-align: center;'>M. Clase</th><th style='border: 1px #ccc solid; text-align: center;'>F. Absoluta</th><th style='border: 1px #ccc solid; text-align: center;'>F. Relativa</th><th style='border: 1px #ccc solid; text-align: center;'>F. Acumulada</th></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>1</td><td style='border: 1px #ccc solid; text-align: center;'>0.9</td><td style='border: 1px #ccc solid; text-align: center;'>1.95</td><td style='border: 1px #ccc solid; text-align: center;'>1.425</td><td style='border: 1px #ccc solid; text-align: center;'>4</td><td style='border: 1px #ccc solid; text-align: center;'>13.333%</td><td style='border: 1px #ccc solid; text-align: center;'>13.333%</td></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>2</td><td style='border: 1px #ccc solid; text-align: center;'>1.95</td><td style='border: 1px #ccc solid; text-align: center;'>3.0</td><td style='border: 1px #ccc solid; text-align: center;'>2.475</td><td style='border: 1px #ccc solid; text-align: center;'>8</td><td style='border: 1px #ccc solid; text-align: center;'>26.667%</td><td style='border: 1px #ccc solid; text-align: center;'>40.0%</td></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>3</td><td style='border: 1px #ccc solid; text-align: center;'>3.0</td><td style='border: 1px #ccc solid; text-align: center;'>4.05</td><td style='border: 1px #ccc solid; text-align: center;'>3.525</td><td style='border: 1px #ccc solid; text-align: center;'>8</td><td style='border: 1px #ccc solid; text-align: center;'>26.667%</td><td style='border: 1px #ccc solid; text-align: center;'>66.667%</td></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>4</td><td style='border: 1px #ccc solid; text-align: center;'>4.05</td><td style='border: 1px #ccc solid; text-align: center;'>5.1</td><td style='border: 1px #ccc solid; text-align: center;'>4.575</td><td style='border: 1px #ccc solid; text-align: center;'>5</td><td style='border: 1px #ccc solid; text-align: center;'>16.667%</td><td style='border: 1px #ccc solid; text-align: center;'>83.334%</td></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>5</td><td style='border: 1px #ccc solid; text-align: center;'>5.1</td><td style='border: 1px #ccc solid; text-align: center;'>6.15</td><td style='border: 1px #ccc solid; text-align: center;'>5.625</td><td style='border: 1px #ccc solid; text-align: center;'>4</td><td style='border: 1px #ccc solid; text-align: center;'>13.333%</td><td style='border: 1px #ccc solid; text-align: center;'>96.667%</td></tr><tr><td style='border: 1px #ccc solid; text-align: center;'>6</td><td style='border: 1px #ccc solid; text-align: center;'>6.15</td><td style='border: 1px #ccc solid; text-align: center;'>7.2</td><td style='border: 1px #ccc solid; text-align: center;'>6.675</td><td style='border: 1px #ccc solid; text-align: center;'>1</td><td style='border: 1px #ccc solid; text-align: center;'>3.333%</td><td style='border: 1px #ccc solid; text-align: center;'>100.0%</td></tr></table></center>
