# %%
import Ejercicios.Eje12 as e12
import Ejercicios.Eje12b as eb

# %%
datos = [250,790,470,510,500,330,300,750,580,740,420,260,440,770,400,540,530,330,390,380,340,460,530,260,410,360,270,510,630,330]
datosb = [300,400,500,600,700,800]
e12.histograma_calorías(datos)
eb.ojiva_calorías(datosb)
